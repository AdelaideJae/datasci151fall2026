# %% [markdown]
# This is my first markdown cell

# %% [markdown]
# ### this is my second markdown cell

# %% [markdown]
# ###### this is my third markdown cell

# %%
print("My name is Adelaide Abrams")
# Out:
# My name is Adelaide Abrams
